# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
# %matplotlib inline

# %%
df = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes.value_counts()
# Out:
# object     5
# int64      5
# float64    2
# dtype: int64

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df_obj=df.dtypes[df.dtypes=="object"].index

# %%
df_obj
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df_obj]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
df_int=df.dtypes[df.dtypes=="int64"].index
df_int
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df[df_int]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# 5              6         0       3      0      0
# 6              7         0       1      0      0
# 7              8         0       3      3      1
# 8              9         1       3      0      2
# 9             10         1       2      1      0
# 10            11         1       3      1      1
# 11            12         1       1      0      0
# 12            13         0       3      0      0
# 13            14         0       3      1      5
# 14            15         0       3      0      0
# 15            16         1       2      0      0
# 16            17         0       3      4      1
# 17            18         1       2      0      0
# ...

# %%
df_float=df.dtypes[df.dtypes=="float64"].index
df_float
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
df[df_float]
# Out:
#       Age      Fare
# 0    22.0    7.2500
# 1    38.0   71.2833
# 2    26.0    7.9250
# 3    35.0   53.1000
# 4    35.0    8.0500
# 5     NaN    8.4583
# 6    54.0   51.8625
# 7     2.0   21.0750
# 8    27.0   11.1333
# 9    14.0   30.0708
# 10    4.0   16.7000
# 11   58.0   26.5500
# 12   20.0    8.0500
# 13   39.0   31.2750
# 14   14.0    7.8542
# 15   55.0   16.0000
# 16    2.0   29.1250
# 17    NaN   13.0000
# 18   31.0   18.0000
# 19    NaN    7.2250
# 20   35.0   26.0000
# 21   34.0   13.0000
# 22   15.0    8.0292
# 23   28.0   35.5000
# 24    8.0   21.0750
# 25   38.0   31.3875
# 26    NaN    7.2250
# 27   19.0  263.0000
# 28    NaN    7.8792
# 29    NaN    7.8958
# ..    ...       ...
# 126   NaN    7.7500
# 127  24.0    7.1417
# 128   NaN   22.3583
# 129  45.0    6.9750
# 130  33.0    7.8958
# 131  20.0    7.0500
# 132  47.0   14.5000
# 133  29.0   26.0000
# 134  25.0   13.0000
# 135  23.0   15.0458
# 136  19.0   26.2833
# 137  37.0   53.1000
# 138  16.0    9.2167
# ...

# %%
df[['Name','Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
sorted(df['Name'])[5:50:4]
# Out:
# ['Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Bateman, Rev. Robert James',
#  'Bonnell, Miss. Elizabeth',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Celotti, Mr. Francesco',
#  'Coelho, Mr. Domingos Fernandeo',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Dowdell, Miss. Elizabeth',
#  'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#  'Fortune, Mr. Charles Alexander',
#  'Giglio, Mr. Victor']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S

# %%
df.iloc[0:20,0:2]
# Out:
#     PassengerId  Survived
# 0             1         0
# 1             2         1
# 2             3         1
# 3             4         1
# 4             5         0
# 5             6         0
# 6             7         0
# 7             8         0
# 8             9         1
# 9            10         1
# 10           11         1
# 11           12         1
# 12           13         0
# 13           14         0
# 14           15         0
# 15           16         1
# 16           17         0
# 17           18         1
# 18           19         0
# 19           20         1

# %%
df.loc[0:2,"Name":"Fare"]
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare
# 0      0         A/5 21171   7.2500
# 1      0          PC 17599  71.2833
# 2      0  STON/O2. 3101282   7.9250

# %%
df["Sex"].value_counts()
# Out:
# male      100
# female     56
# Name: Sex, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# 0.8012820512820513

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df.groupby("Sex").describe()
# Out:
#        PassengerId                                                      \
#              count    mean        std  min    25%   50%     75%    max
# Sex
# female        56.0  68.125  46.151554  2.0  28.25  58.0  110.50  152.0
# male         100.0  84.310  43.785911  1.0  50.50  87.5  121.25  156.0
#
#        Survived            ... Parch        Fare                               \
#           count      mean  ...   75%  max  count       mean        std    min
# Sex                        ...
# female     56.0  0.714286  ...   1.0  5.0   56.0  28.460639  40.144759  7.225
# male      100.0  0.140000  ...   0.0  5.0  100.0  27.912998  39.180974  6.750
#
#
#            25%      50%      75%    max
# Sex
# female  9.7375  15.9250  26.8500  263.0
# male    7.9177  12.0125  34.4448  263.0
#
# [2 rows x 56 columns]

# %% [markdown]
# # REFERENCE LINKS

# %% [markdown]
# # https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
