# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from numpy.random import randn, randint, uniform, sample

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linewidth=5, linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(x,y,'b+--')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df = iris.drop(['species'], axis = 1)
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar()

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.559620  0.226409  1.007685  0.051916
# 1 -0.352777  0.080956 -0.662984  0.528514
# 2 -1.002271 -1.067906  2.060008  1.102252
# 3  0.064716 -0.702946 -1.467391  0.372281
# 4  0.952896 -1.553458  1.309428  0.149193
# 5 -0.185289 -0.045552 -1.359954  1.803809
# 6 -0.238650  0.869100 -0.238365 -0.485487
# 7 -0.464421 -0.852408  0.488888 -0.337978
# 8  0.033747  2.003560 -0.355769 -1.127212
# 9  1.589969  1.176191  2.014083 -0.560398

# %%
df.plot(kind='bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.plot.scatter(x='petal_length', y = 'petal_width', label = 'Length')

# %%
iris.iloc[1,:4].plot.pie(figsize = (10,10))

# %%
iris.iloc[:3,:3].T.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CACFFC29B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CACFFED3C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001CAD0015828>],
#       dtype=object)
